# %% [markdown]
# <font size="5">
#
# This is my first Jupyter notebook

# %%
print("My name is Ashley Huang")

# %% [markdown]
# ![Screenshot 2025-09-09 at 5.49.00 PM.png](<attachment:Screenshot 2025-09-09 at 5.49.00 PM.png>)
